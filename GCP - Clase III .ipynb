# %%
import os
from pprint import pprint
from google.cloud import storage

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'/content/eminent-cache-401815-f71ed7566cd7.json'

storage_client = storage.Client()

# %%
for bucket in storage_client.list_buckets(max_results=100):
    print(bucket)

# %% [markdown]
# # **Creando Bucket desde Phyton**

# %%
bucket_name = 'datalake-dmc-hmsq22'

# create a new bucket
bucket = storage_client.bucket(bucket_name)
bucket.storage_class = 'STANDARD' # Archive | Nearline | Standard https://cloud.google.com/storage/docs/storage-classes
bucket.location = 'US' # https://cloud.google.com/storage/docs/locations
bucket = storage_client.create_bucket(bucket) # returns Bucket object

pprint(vars(bucket))

bucket.name
bucket._properties['selfLink']
bucket._properties['id']
bucket._properties['location']
bucket._properties['timeCreated']
bucket._properties['storageClass']
bucket._properties['timeCreated']
bucket._properties['updated']
# Out:
# <ipython-input-4-c361b2ad717c>:6: DeprecationWarning: Assignment to 'Bucket.location' is deprecated, as it is only valid before the bucket is created. Instead, pass the location to `Bucket.create`.
#   bucket.location = 'US' # https://cloud.google.com/storage/docs/locations
# {'_acl': <google.cloud.storage.acl.BucketACL object at 0x7fa972be5450>,
#  '_changes': set(),
#  '_client': <google.cloud.storage.client.Client object at 0x7fa9a80c2f50>,
#  '_default_object_acl': <google.cloud.storage.acl.DefaultObjectACL object at 0x7fa972be6a40>,
#  '_label_removals': set(),
#  '_properties': {'etag': 'CAE=',
#                  'iamConfiguration': {'bucketPolicyOnly': {'enabled': False},
#                                       'publicAccessPrevention': 'inherited',
#                                       'uniformBucketLevelAccess': {'enabled': False}},
#                  'id': 'datalake-dmc-hmsq22',
#                  'kind': 'storage#bucket',
#                  'location': 'US',
#                  'locationType': 'multi-region',
#                  'metageneration': '1',
#                  'name': 'datalake-dmc-hmsq22',
#                  'projectNumber': '461403346175',
#                  'rpo': 'DEFAULT',
#                  'selfLink': 'https://www.googleapis.com/storage/v1/b/datalake-dmc-hmsq22',
#                  'storageClass': 'STANDARD',
#                  'timeCreated': '2023-10-18T03:17:36.119Z',
#                  'updated': '2023-10-18T03:17:36.119Z'},
#  '_user_project': None,
#  'name': 'datalake-dmc-hmsq22'}
# '2023-10-18T03:17:36.119Z'

# %%
"""
Get Bucket
"""
my_bucket = storage_client.get_bucket(bucket_name)
pprint(vars(my_bucket))
# Out:
# {'_acl': <google.cloud.storage.acl.BucketACL object at 0x7fa972be5900>,
#  '_changes': set(),
#  '_client': <google.cloud.storage.client.Client object at 0x7fa9a80c2f50>,
#  '_default_object_acl': <google.cloud.storage.acl.DefaultObjectACL object at 0x7fa972be5d50>,
#  '_label_removals': set(),
#  '_properties': {'etag': 'CAE=',
#                  'iamConfiguration': {'bucketPolicyOnly': {'enabled': False},
#                                       'publicAccessPrevention': 'inherited',
#                                       'uniformBucketLevelAccess': {'enabled': False}},
#                  'id': 'datalake-dmc-hmsq22',
#                  'kind': 'storage#bucket',
#                  'location': 'US',
#                  'locationType': 'multi-region',
#                  'metageneration': '1',
#                  'name': 'datalake-dmc-hmsq22',
#                  'projectNumber': '461403346175',
#                  'rpo': 'DEFAULT',
#                  'selfLink': 'https://www.googleapis.com/storage/v1/b/datalake-dmc-hmsq22',
#                  'storageClass': 'STANDARD',
#                  'timeCreated': '2023-10-18T03:17:36.119Z',
#                  'updated': '2023-10-18T03:17:36.119Z'},
#  '_user_project': None,
#  'name': 'datalake-dmc-hmsq22'}

# %% [markdown]
# # **Cargando Archivo**

# %%
"""
Upload File
"""
def upload_to_bucket(blob_name, file_path, bucket_name):
    '''
    Upload file to a bucket
    : blob_name  (str) - object name
    : file_path (str)
    : bucket_name (str)
    '''
    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(blob_name)
    blob.upload_from_filename(file_path)
    return blob

response = upload_to_bucket('raw/Discounts_cargado.csv', '/content/Discounts_cargado.csv', bucket_name)
# response = upload_to_bucket('/docs/requirementABC', 'requirements.txt', bucket_name)

# %%
# !cd /content

# %%
"""
Download File By Blob Name
"""
def download_file_from_bucket(blog_name, file_path, bucket_name):
    bucket = storage_client.get_bucket(bucket_name)
    blob = bucket.blob(blog_name)
    with open(file_path, 'wb') as f:
        storage_client.download_blob_to_file(blob, f)
    print('Saved')

download_file_from_bucket('raw/Discounts_cargado.csv', './Discounts_descargado.csv', bucket_name)
# Out:
# Saved

# %%
"""
Download File By Passing URI Path
"""
def download_file_uri(uri, file_path):
    with open(file_path, 'wb') as f:
        storage_client.download_blob_to_file(uri, f)
    print('Saved')

uri = 'gs://datalake-dmc-hmsq22/raw/Discounts_cargado.csv'
download_file_uri(uri, './Discounts_uri.csv')
# Out:
# Saved
