# %% [markdown]
# #Seccion A
# ##Seccion B

# %%
# @title Formulario: Datos personales
nombre = "Octvavio" # @param {type:"string"}
edad = 19 # @param {type:"slider", min:0, max:120, step:1}
residencia = "Colombia" # @param ["Colombia", "Mexico"]
nacimiento = "2023-11-21" # @param {type:"date"}
donador = True # @param {type:"boolean"}
color = "azul" # @param ["rojo", "verde", "azul"]

# %%
from matplotlib import pyplot as plt
plt.pie([25,25,25,25], labels =["Mexico", "Colombia", "España", "Perú"])
plt.show

# %%
#https://sheets.google.com/
import gspread
import pandas as pd
from google.colab import auth
from google.auth import default

#Credenciales para acceso a cuenta
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

#Abre hoja de calculo
hoja = gc.open("Copia de BD_CxC").sheet1

#Lee e imprime hoja de calculo
renglones = hoja.get_all_values()
df = pd.DataFrame.from_records(renglones)
df
